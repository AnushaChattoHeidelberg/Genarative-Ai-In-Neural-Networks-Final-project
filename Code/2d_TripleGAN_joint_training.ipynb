# %% [markdown]
# # Triple Generative Adversarial Networks with MedNIST Dataset
#
#
#
# ## Setup environment

# %%
# !pip install monai
# !pip install monai-generative
# !pip install lpips
# Out:
# Collecting monai
#   Downloading monai-1.3.0-202310121228-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from monai) (1.25.2)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai) (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.9->monai)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 47.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.9->monai)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 67.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.9->monai)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 55.7 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.9->monai)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.9->monai)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.9->monai)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.7 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.9->monai)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 4.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.9->monai)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.0 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.9->monai)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.1 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.9->monai)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.7 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.9->monai)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9->monai)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 31.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->monai) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, monai
# Successfully installed monai-1.3.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105
# Collecting monai-generative
#   Downloading monai_generative-0.2.3-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: monai>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from monai-generative) (1.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from monai>=1.3.0->monai-generative) (1.25.2)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from monai>=1.3.0->monai-generative) (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->monai>=1.3.0->monai-generative) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9->monai>=1.3.0->monai-generative) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->monai>=1.3.0->monai-generative) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->monai>=1.3.0->monai-generative) (1.3.0)
# Installing collected packages: monai-generative
# Successfully installed monai-generative-0.2.3
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from lpips) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from lpips) (0.17.1+cu121)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from lpips) (1.25.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from lpips) (1.11.4)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.10/dist-packages (from lpips) (4.66.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=0.4.0->lpips) (12.4.99)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.2.1->lpips) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.0->lpips) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.0->lpips) (1.3.0)
# Installing collected packages: lpips
# Successfully installed lpips-0.1.4

# %% [markdown]
# ## Setup imports

# %%
import os
import shutil
import tempfile
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
from monai import transforms
from monai.apps import MedNISTDataset
from monai.config import print_config
from monai.data import CacheDataset, DataLoader,Dataset
from monai.utils import first, set_determinism
from torch.nn import L1Loss
from tqdm import tqdm

from generative.losses import PatchAdversarialLoss, PerceptualLoss
from generative.networks.nets import VQVAE, PatchDiscriminator

print_config()
# Out:
# MONAI version: 1.3.0
# Numpy version: 1.25.2
# Pytorch version: 2.2.1+cu121
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 865972f7a791bf7b42efbcd87c8402bd865b329e
# MONAI __file__: /usr/local/lib/python3.10/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 4.0.2
# scikit-image version: 0.19.3
# scipy version: 1.11.4
# Pillow version: 9.4.0
# Tensorboard version: 2.15.2
# gdown version: 4.7.3
# TorchVision version: 0.17.1+cu121
# tqdm version: 4.66.2
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.5
# pandas version: 1.5.3
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: 4.38.2
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# ## Setup data directory
#
# You can specify a directory with the MONAI_DATA_DIRECTORY environment variable.
#
# This allows you to save results and reuse downloads.
#
# If not specified a temporary directory will be used.

# %%
directory = os.environ.get("MONAI_DATA_DIRECTORY")
root_dir = tempfile.mkdtemp() if directory is None else directory
print(root_dir)
# Out:
# /tmp/tmputwd4l2c

# %% [markdown]
# ## Set deterministic training for reproducibility

# %%
set_determinism(42)

# %% [markdown]
# ## Setup MedNIST Dataset and training and validation dataloaders

# %%
train_data = MedNISTDataset(root_dir=root_dir, section="training", download=True, seed=0)
train_datalist = [{"image": item["image"]} for item in train_data.data if item["class_name"] == "HeadCT"]
image_size = 64
train_transforms = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image"]),
        transforms.EnsureChannelFirstd(keys=["image"]),
        transforms.ScaleIntensityRanged(keys=["image"], a_min=0.0, a_max=255.0, b_min=0.0, b_max=1.0, clip=True),
        transforms.RandAffined(
            keys=["image"],
            rotate_range=[(-np.pi / 36, np.pi / 36), (-np.pi / 36, np.pi / 36)],
            translate_range=[(-1, 1), (-1, 1)],
            scale_range=[(-0.05, 0.05), (-0.05, 0.05)],
            spatial_size=[image_size, image_size],
            padding_mode="zeros",
            prob=0.5,
        ),
    ]
)
train_ds = Dataset(data=train_datalist, transform=train_transforms)
train_loader = DataLoader(train_ds, batch_size=128, shuffle=True, num_workers=4, persistent_workers=True)
# Out:
# MedNIST.tar.gz: 59.0MB [00:00, 88.5MB/s]
# 2024-03-24 07:57:25,560 - INFO - Downloaded: /tmp/tmputwd4l2c/MedNIST.tar.gz
# 2024-03-24 07:57:25,698 - INFO - Verified 'MedNIST.tar.gz', md5: 0bc7306e7427e00ad1c5526a6677552d.
# 2024-03-24 07:57:25,704 - INFO - Writing into directory: /tmp/tmputwd4l2c.
# Loading dataset: 100%|██████████| 47164/47164 [00:35<00:00, 1332.11it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ### Visualization of the training images

# %%
check_data = first(train_loader)
print(f"batch shape: {check_data['image'].shape}")
image_visualization = torch.cat(
    [check_data["image"][0, 0], check_data["image"][1, 0], check_data["image"][2, 0], check_data["image"][3, 0]], dim=1
)
plt.figure("training images", (12, 6))
plt.imshow(image_visualization, vmin=0, vmax=1, cmap="gray")
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# batch shape: torch.Size([128, 1, 64, 64])

# %%
val_data = MedNISTDataset(root_dir=root_dir, section="validation", download=True, seed=0)
val_datalist = [{"image": item["image"]} for item in val_data.data if item["class_name"] == "HeadCT"]
val_transforms = transforms.Compose(
    [
        transforms.LoadImaged(keys=["image"]),
        transforms.EnsureChannelFirstd(keys=["image"]),
        transforms.ScaleIntensityRanged(keys=["image"], a_min=0.0, a_max=255.0, b_min=0.0, b_max=1.0, clip=True),
    ]
)
val_ds = Dataset(data=val_datalist, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=128, shuffle=True, num_workers=4, persistent_workers=True)
# Out:
# 2024-03-24 07:58:26,131 - INFO - Verified 'MedNIST.tar.gz', md5: 0bc7306e7427e00ad1c5526a6677552d.
# 2024-03-24 07:58:26,137 - INFO - File exists: /tmp/tmputwd4l2c/MedNIST.tar.gz, skipped downloading.
# 2024-03-24 07:58:26,142 - INFO - Non-empty folder exists in /tmp/tmputwd4l2c/MedNIST, skipped extracting.
# Loading dataset: 100%|██████████| 5895/5895 [00:04<00:00, 1297.38it/s]

# %% [markdown]
# ### Define network, scheduler and optimizer
# At this step, we instantiate the MONAI components to create a VQVAE and a Discriminator model. We are using the
# Discriminator to train the Autoencoder with a Generative Adversarial loss, where the VQVAE works as a Generator.
# The VQVAE is trained to minimize the reconstruction error, a perceptual loss using AlexNet as the embedding model
# and an adversarial loss versus the performance of the Discriminator.

# %%
device = torch.device("cuda")

model = VQVAE(
    spatial_dims=2,
    in_channels=1,
    out_channels=1,
    num_channels=(128, 512),
    num_res_channels=512,
    num_res_layers=2,
    downsample_parameters=((2, 4, 1, 1), (2, 4, 1, 1)),
    upsample_parameters=((2, 4, 1, 1, 0), (2, 4, 1, 1, 0)),
    num_embeddings=256,
    embedding_dim=32,
)
model.to(device)

discriminator = PatchDiscriminator(spatial_dims=2, in_channels=1, num_layers_d=3, num_channels=64)
discriminator.to(device)
classifier = PatchDiscriminator(spatial_dims=2, in_channels=1, num_layers_d=3, num_channels=64)
classifier.to(device)

perceptual_loss = PerceptualLoss(spatial_dims=2, network_type="alex")
perceptual_loss.to(device)

optimizer_g = torch.optim.Adam(model.parameters(), lr=1e-4)
optimizer_d = torch.optim.Adam(discriminator.parameters(), lr=5e-4)
optimizer_c = torch.optim.Adam(classifier.parameters(), lr=5e-4)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:03<00:00, 77.9MB/s]

# %%
l1_loss = L1Loss()
adv_loss = PatchAdversarialLoss(criterion="least_squares")
classider_loss=PatchAdversarialLoss(criterion="bce")
adv_weight = 0.01
perceptual_weight = 0.001

# %% [markdown]
# ### Model training

# %%
n_epochs = 100
val_interval = 10
epoch_recon_loss_list = []
epoch_gen_loss_list = []
epoch_disc_loss_list = []
val_recon_epoch_loss_list = []
intermediary_images = []
epoch_classifier_loss_list=[]
n_example_images = 4

total_start = time.time()
for epoch in range(n_epochs):
    model.train()
    discriminator.train()
    classifier.eval()
    epoch_loss = 0
    gen_epoch_loss = 0
    disc_epoch_loss = 0
    classifier_epoch_loss = 0
    progress_bar = tqdm(enumerate(train_loader), total=len(train_loader), ncols=200)
    progress_bar.set_description(f"Epoch {epoch}")
    for step, batch in progress_bar:
        images = batch["image"].to(device)
        optimizer_g.zero_grad(set_to_none=True)

        reconstruction, quantization_loss = model(images=images)

        # Generator part
        logits_fake = discriminator(reconstruction.contiguous().float())[-1]
        logits_fake_c = classifier(reconstruction.contiguous().float())[-1]


        recons_loss = l1_loss(reconstruction.float(), images.float())
        p_loss = perceptual_loss(reconstruction.float(), images.float())
        generator_loss = adv_loss(logits_fake, target_is_real=True, for_discriminator=False)
        generator_loss_c=classider_loss(logits_fake_c, target_is_real=True, for_discriminator=False)
        loss_g = recons_loss + quantization_loss + perceptual_weight * p_loss + adv_weight * (generator_loss+generator_loss_c)

        loss_g.backward(retain_graph=True)
        optimizer_g.step()


        # Discriminator part
        optimizer_d.zero_grad(set_to_none=True)
        optimizer_c.zero_grad(set_to_none=True)

        logits_fake = discriminator(reconstruction.contiguous().detach())[-1]
        loss_d_fake = adv_loss(logits_fake, target_is_real=False, for_discriminator=True)
        logits_real = discriminator(images.contiguous().detach())[-1]
        loss_d_real = adv_loss(logits_real, target_is_real=True, for_discriminator=True)
        discriminator_loss = (loss_d_fake + loss_d_real) * 0.5

        loss_d = adv_weight * discriminator_loss

        # Classifier part

        logits_fake = classifier(reconstruction.contiguous().detach())[-1]
        loss_c_fake = classider_loss(logits_fake, target_is_real=False, for_discriminator=True)
        logits_real = classifier(images.contiguous().detach())[-1]
        loss_c_real = classider_loss(logits_real, target_is_real=True, for_discriminator=True)
        classifier_loss = (loss_c_fake + loss_c_real) * 0.5

        loss_c = adv_weight * classifier_loss

        loss_d.backward(retain_graph=True)
        optimizer_d.step()

        loss_c.backward(retain_graph=True)
        optimizer_c.step()


        epoch_loss += recons_loss.item()
        gen_epoch_loss += generator_loss.item()
        disc_epoch_loss += discriminator_loss.item()
        classifier_epoch_loss += classifier_loss.item()

        progress_bar.set_postfix(
            {
                "recons_loss": epoch_loss / (step + 1),
                "gen_loss": gen_epoch_loss / (step + 1),
                "disc_loss": disc_epoch_loss / (step + 1),
                "classifier_loss": classifier_epoch_loss / (step + 1),

            }
        )
    epoch_recon_loss_list.append(epoch_loss / (step + 1))
    epoch_gen_loss_list.append(gen_epoch_loss / (step + 1))
    epoch_disc_loss_list.append(disc_epoch_loss / (step + 1))
    epoch_classifier_loss_list.append(classifier_epoch_loss / (step + 1))

    if (epoch + 1) % val_interval == 0:
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for val_step, batch in enumerate(val_loader, start=1):
                images = batch["image"].to(device)

                reconstruction, quantization_loss = model(images=images)

                # get the first sammple from the first validation batch for visualization
                # purposes
                if val_step == 1:
                    intermediary_images.append(reconstruction[:n_example_images, 0])


                recons_loss = l1_loss(reconstruction.float(), images.float())

                val_loss += recons_loss.item()

        val_loss /= val_step
        val_recon_epoch_loss_list.append(val_loss)

total_time = time.time() - total_start
print(f"train completed, total time: {total_time}.")
# Out:
# Epoch 0: 100%|███████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.107, gen_loss=0.952, disc_loss=0.444, classifier_loss=0.662]
# Epoch 1: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.75it/s, recons_loss=0.0522, gen_loss=0.684, disc_loss=0.281, classifier_loss=0.693]
# Epoch 2: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.73it/s, recons_loss=0.0439, gen_loss=0.508, disc_loss=0.298, classifier_loss=0.693]
# Epoch 3: 100%|███████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0388, gen_loss=0.39, disc_loss=0.268, classifier_loss=0.693]
# Epoch 4: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0353, gen_loss=0.303, disc_loss=0.245, classifier_loss=0.693]
# Epoch 5: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0325, gen_loss=0.338, disc_loss=0.249, classifier_loss=0.693]
# Epoch 6: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0301, gen_loss=0.291, disc_loss=0.246, classifier_loss=0.693]
# Epoch 7: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.75it/s, recons_loss=0.0282, gen_loss=0.311, disc_loss=0.241, classifier_loss=0.693]
# Epoch 8: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0278, gen_loss=0.298, disc_loss=0.239, classifier_loss=0.693]
# Epoch 9: 100%|███████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0264, gen_loss=0.327, disc_loss=0.25, classifier_loss=0.693]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Epoch 10: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0261, gen_loss=0.294, disc_loss=0.24, classifier_loss=0.693]
# Epoch 11: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0259, gen_loss=0.297, disc_loss=0.241, classifier_loss=0.693]
# Epoch 12: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.73it/s, recons_loss=0.0256, gen_loss=0.299, disc_loss=0.242, classifier_loss=0.693]
# Epoch 13: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.74it/s, recons_loss=0.0246, gen_loss=0.314, disc_loss=0.246, classifier_loss=0.693]
# Epoch 14: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0242, gen_loss=0.337, disc_loss=0.253, classifier_loss=0.693]
# Epoch 15: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0249, gen_loss=0.331, disc_loss=0.252, classifier_loss=0.693]
# Epoch 16: 100%|███████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.74it/s, recons_loss=0.0247, gen_loss=0.3, disc_loss=0.241, classifier_loss=0.693]
# Epoch 17: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.74it/s, recons_loss=0.0244, gen_loss=0.303, disc_loss=0.24, classifier_loss=0.693]
# Epoch 18: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.74it/s, recons_loss=0.0248, gen_loss=0.301, disc_loss=0.241, classifier_loss=0.693]
# Epoch 19: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0239, gen_loss=0.309, disc_loss=0.243, classifier_loss=0.693]
# Epoch 20: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0239, gen_loss=0.313, disc_loss=0.25, classifier_loss=0.693]
# Epoch 21: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0228, gen_loss=0.293, disc_loss=0.242, classifier_loss=0.693]
# Epoch 22: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.72it/s, recons_loss=0.0225, gen_loss=0.288, disc_loss=0.239, classifier_loss=0.693]
# Epoch 23: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.72it/s, recons_loss=0.0223, gen_loss=0.329, disc_loss=0.25, classifier_loss=0.693]
# Epoch 24: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0222, gen_loss=0.325, disc_loss=0.244, classifier_loss=0.693]
# Epoch 25: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0222, gen_loss=0.312, disc_loss=0.243, classifier_loss=0.693]
# Epoch 26: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0217, gen_loss=0.334, disc_loss=0.248, classifier_loss=0.693]
# Epoch 27: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.73it/s, recons_loss=0.0219, gen_loss=0.33, disc_loss=0.246, classifier_loss=0.693]
# Epoch 28: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.75it/s, recons_loss=0.0215, gen_loss=0.331, disc_loss=0.237, classifier_loss=0.693]
# Epoch 29: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0222, gen_loss=0.307, disc_loss=0.24, classifier_loss=0.693]
# Epoch 30: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.75it/s, recons_loss=0.0226, gen_loss=0.312, disc_loss=0.249, classifier_loss=0.693]
# Epoch 31: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0225, gen_loss=0.349, disc_loss=0.253, classifier_loss=0.693]
# Epoch 32: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.74it/s, recons_loss=0.023, gen_loss=0.322, disc_loss=0.234, classifier_loss=0.693]
# Epoch 33: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.75it/s, recons_loss=0.0218, gen_loss=0.306, disc_loss=0.243, classifier_loss=0.693]
# Epoch 34: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0211, gen_loss=0.317, disc_loss=0.231, classifier_loss=0.693]
# Epoch 35: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0213, gen_loss=0.306, disc_loss=0.238, classifier_loss=0.693]
# Epoch 36: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0213, gen_loss=0.321, disc_loss=0.234, classifier_loss=0.693]
# Epoch 37: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.74it/s, recons_loss=0.0213, gen_loss=0.327, disc_loss=0.239, classifier_loss=0.693]
# Epoch 38: 100%|███████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0214, gen_loss=0.32, disc_loss=0.23, classifier_loss=0.693]
# Epoch 39: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0228, gen_loss=0.311, disc_loss=0.244, classifier_loss=0.693]
# Epoch 40: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0224, gen_loss=0.324, disc_loss=0.23, classifier_loss=0.693]
# Epoch 41: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0225, gen_loss=0.338, disc_loss=0.24, classifier_loss=0.693]
# Epoch 42: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.75it/s, recons_loss=0.0218, gen_loss=0.325, disc_loss=0.236, classifier_loss=0.693]
# Epoch 43: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.75it/s, recons_loss=0.0222, gen_loss=0.351, disc_loss=0.223, classifier_loss=0.693]
# Epoch 44: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0223, gen_loss=0.326, disc_loss=0.234, classifier_loss=0.693]
# Epoch 45: 100%|███████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0217, gen_loss=0.401, disc_loss=0.2, classifier_loss=0.693]
# Epoch 46: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.80it/s, recons_loss=0.0237, gen_loss=0.389, disc_loss=0.211, classifier_loss=0.693]
# Epoch 47: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0232, gen_loss=0.406, disc_loss=0.197, classifier_loss=0.693]
# Epoch 48: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0232, gen_loss=0.409, disc_loss=0.21, classifier_loss=0.693]
# Epoch 49: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0237, gen_loss=0.371, disc_loss=0.234, classifier_loss=0.693]
# Epoch 50: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0232, gen_loss=0.361, disc_loss=0.219, classifier_loss=0.693]
# Epoch 51: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0252, gen_loss=0.383, disc_loss=0.226, classifier_loss=0.693]
# Epoch 52: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.72it/s, recons_loss=0.0236, gen_loss=0.363, disc_loss=0.23, classifier_loss=0.693]
# Epoch 53: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.73it/s, recons_loss=0.0235, gen_loss=0.379, disc_loss=0.237, classifier_loss=0.693]
# Epoch 54: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0232, gen_loss=0.366, disc_loss=0.23, classifier_loss=0.693]
# Epoch 55: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0229, gen_loss=0.306, disc_loss=0.25, classifier_loss=0.693]
# Epoch 56: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0221, gen_loss=0.337, disc_loss=0.232, classifier_loss=0.693]
# Epoch 57: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.73it/s, recons_loss=0.0224, gen_loss=0.339, disc_loss=0.229, classifier_loss=0.693]
# Epoch 58: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0218, gen_loss=0.332, disc_loss=0.236, classifier_loss=0.693]
# Epoch 59: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0223, gen_loss=0.36, disc_loss=0.219, classifier_loss=0.693]
# Epoch 60: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0219, gen_loss=0.337, disc_loss=0.231, classifier_loss=0.693]
# Epoch 61: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0225, gen_loss=0.336, disc_loss=0.245, classifier_loss=0.693]
# Epoch 62: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0224, gen_loss=0.357, disc_loss=0.222, classifier_loss=0.693]
# Epoch 63: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0229, gen_loss=0.353, disc_loss=0.233, classifier_loss=0.693]
# Epoch 64: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0227, gen_loss=0.36, disc_loss=0.228, classifier_loss=0.693]
# Epoch 65: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0224, gen_loss=0.345, disc_loss=0.223, classifier_loss=0.693]
# Epoch 66: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.75it/s, recons_loss=0.0229, gen_loss=0.366, disc_loss=0.223, classifier_loss=0.693]
# Epoch 67: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0224, gen_loss=0.373, disc_loss=0.216, classifier_loss=0.693]
# Epoch 68: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0222, gen_loss=0.366, disc_loss=0.227, classifier_loss=0.693]
# Epoch 69: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0222, gen_loss=0.392, disc_loss=0.21, classifier_loss=0.693]
# Epoch 70: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0232, gen_loss=0.397, disc_loss=0.224, classifier_loss=0.693]
# Epoch 71: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.74it/s, recons_loss=0.0231, gen_loss=0.407, disc_loss=0.205, classifier_loss=0.693]
# Epoch 72: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0228, gen_loss=0.392, disc_loss=0.22, classifier_loss=0.693]
# Epoch 73: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0227, gen_loss=0.404, disc_loss=0.221, classifier_loss=0.693]
# Epoch 74: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0224, gen_loss=0.366, disc_loss=0.215, classifier_loss=0.693]
# Epoch 75: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0228, gen_loss=0.39, disc_loss=0.219, classifier_loss=0.693]
# Epoch 76: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.74it/s, recons_loss=0.0228, gen_loss=0.402, disc_loss=0.205, classifier_loss=0.693]
# Epoch 77: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0233, gen_loss=0.388, disc_loss=0.219, classifier_loss=0.693]
# Epoch 78: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0223, gen_loss=0.37, disc_loss=0.229, classifier_loss=0.693]
# Epoch 79: 100%|████████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.022, gen_loss=0.4, disc_loss=0.215, classifier_loss=0.693]
# Epoch 80: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0225, gen_loss=0.395, disc_loss=0.216, classifier_loss=0.693]
# Epoch 81: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.023, gen_loss=0.407, disc_loss=0.231, classifier_loss=0.693]
# Epoch 82: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.022, gen_loss=0.406, disc_loss=0.218, classifier_loss=0.693]
# Epoch 83: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0226, gen_loss=0.409, disc_loss=0.19, classifier_loss=0.693]
# Epoch 84: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0232, gen_loss=0.427, disc_loss=0.206, classifier_loss=0.693]
# Epoch 85: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0235, gen_loss=0.396, disc_loss=0.213, classifier_loss=0.693]
# Epoch 86: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.78it/s, recons_loss=0.0229, gen_loss=0.384, disc_loss=0.221, classifier_loss=0.693]
# Epoch 87: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0221, gen_loss=0.412, disc_loss=0.209, classifier_loss=0.693]
# Epoch 88: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0225, gen_loss=0.442, disc_loss=0.208, classifier_loss=1.18]
# Epoch 89: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.74it/s, recons_loss=0.0241, gen_loss=0.431, disc_loss=0.215, classifier_loss=0.725]
# Epoch 90: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.75it/s, recons_loss=0.0223, gen_loss=0.385, disc_loss=0.216, classifier_loss=0.693]
# Epoch 91: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0217, gen_loss=0.418, disc_loss=0.207, classifier_loss=0.693]
# Epoch 92: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0223, gen_loss=0.409, disc_loss=0.204, classifier_loss=0.693]
# Epoch 93: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:34<00:00,  1.80it/s, recons_loss=0.0228, gen_loss=0.422, disc_loss=0.216, classifier_loss=0.693]
# Epoch 94: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0221, gen_loss=0.42, disc_loss=0.203, classifier_loss=0.693]
# Epoch 95: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0223, gen_loss=0.396, disc_loss=0.219, classifier_loss=0.693]
# Epoch 96: 100%|██████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.76it/s, recons_loss=0.0224, gen_loss=0.39, disc_loss=0.222, classifier_loss=0.693]
# Epoch 97: 100%|███████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.79it/s, recons_loss=0.0219, gen_loss=0.426, disc_loss=0.2, classifier_loss=0.693]
# Epoch 98: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:36<00:00,  1.75it/s, recons_loss=0.0221, gen_loss=0.377, disc_loss=0.216, classifier_loss=0.693]
# Epoch 99: 100%|█████████████████████████████████████████████████████████████████████████████| 63/63 [00:35<00:00,  1.77it/s, recons_loss=0.0223, gen_loss=0.405, disc_loss=0.211, classifier_loss=0.693]
# train completed, total time: 3583.192790746689.

# %% [markdown]
# ### Learning curves

# %%
plt.style.use("seaborn-v0_8")
plt.title("Learning Curves", fontsize=20)
plt.plot(np.linspace(1, n_epochs, n_epochs), epoch_recon_loss_list, color="C0", linewidth=2.0, label="Train")
plt.plot(
    np.linspace(val_interval, n_epochs, int(n_epochs / val_interval)),
    val_recon_epoch_loss_list,
    color="C1",
    linewidth=2.0,
    label="Validation",
)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.xlabel("Epochs", fontsize=16)
plt.ylabel("Loss", fontsize=16)
plt.legend(prop={"size": 14})
plt.show()

# %%
n_epochs=100
plt.title("Adversarial Training Curves", fontsize=20)
plt.plot(np.linspace(1, n_epochs, n_epochs), epoch_gen_loss_list, color="C0", linewidth=2.0, label="Generator")
plt.plot(np.linspace(1, n_epochs, n_epochs), epoch_disc_loss_list, color="C1", linewidth=2.0, label="Discriminator")
plt.plot(np.linspace(1, n_epochs, n_epochs), epoch_classifier_loss_list, color="C2", linewidth=2.0, label="Classifier")
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.xlabel("Epochs", fontsize=16)
plt.ylabel("Loss", fontsize=16)
plt.legend(prop={"size": 14})
plt.show()

# %% [markdown]
# ### Checking reconstructions

# %%
# Plot first 4 evaluations
val_samples = np.linspace(val_interval, n_epochs, int(n_epochs / val_interval))
fig, ax = plt.subplots(nrows=6, ncols=1, sharey=True)
for image_n in range(6):
    reconstructions = torch.reshape(intermediary_images[image_n], (64 * n_example_images, 64)).T
    ax[image_n].imshow(reconstructions.cpu(), cmap="gray")
    ax[image_n].set_xticks([])
    ax[image_n].set_yticks([])
    ax[image_n].set_ylabel(f"Epoch {val_samples[image_n]:.0f}")

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].imshow(images[0, 0].detach().cpu(), vmin=0, vmax=1, cmap="gray")
ax[0].axis("off")
ax[0].title.set_text("Inputted Image")
ax[1].imshow(reconstruction[0, 0].detach().cpu(), vmin=0, vmax=1, cmap="gray")
ax[1].axis("off")
ax[1].title.set_text("Reconstruction")
plt.show()

# %%
import matplotlib.pyplot as plt

image_shape = (1,1, 64, 64)
num_of_samples = 5

with torch.no_grad():
    fig, axes = plt.subplots(1, num_of_samples, figsize=(15, 3))

    for n in range(num_of_samples):
        # Pass the random noise through the model
        noise = torch.randn(image_shape).to(device)
        generated_images, loss = model(noise)
        # Plot the generated image
        axes[n].imshow(generated_images.squeeze().cpu().numpy(), cmap='gray')
        axes[n].axis('off')
        axes[n].set_title(f'Generated Image {n+1}')

plt.show()

# %%
for batch in val_loader:
    images = batch["image"].to(device)
    break

# Add noise to the image
noise_std = 0.2
noisy_images = images + noise_std * torch.randn_like(images)

with torch.no_grad():
    reconstructed_images, _ = model(noisy_images)

num_samples = min(images.shape[0], 3)
fig, axes = plt.subplots(num_samples, 3, figsize=(6, num_samples * 3))

for i in range(num_samples):
    axes[i, 0].imshow(images[i, 0].cpu(), cmap='gray')
    axes[i, 0].set_title('Original')
    axes[i, 0].axis('off')

    axes[i, 1].imshow(noisy_images[i, 0].cpu(), cmap='gray')
    axes[i, 1].set_title('Noisy')
    axes[i, 1].axis('off')

    axes[i, 2].imshow(reconstructed_images[i, 0].cpu(), cmap='gray')
    axes[i, 2].set_title('Reconstructed')
    axes[i, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
for batch in val_loader:
    images = batch["image"].to(device)
    break

# Add noise to the image
noise_std = 0.9
noisy_images = images + noise_std * torch.randn_like(images)

with torch.no_grad():
    reconstructed_images, _ = model(noisy_images)

num_samples = min(images.shape[0], 3)
fig, axes = plt.subplots(num_samples, 3, figsize=(6, num_samples * 3))

for i in range(num_samples):
    axes[i, 0].imshow(images[i, 0].cpu(), cmap='gray')
    axes[i, 0].set_title('Original')
    axes[i, 0].axis('off')

    axes[i, 1].imshow(noisy_images[i, 0].cpu(), cmap='gray')
    axes[i, 1].set_title('Noisy')
    axes[i, 1].axis('off')

    axes[i, 2].imshow(reconstructed_images[i, 0].cpu(), cmap='gray')
    axes[i, 2].set_title('Reconstructed')
    axes[i, 2].axis('off')

plt.tight_layout()
plt.show()
